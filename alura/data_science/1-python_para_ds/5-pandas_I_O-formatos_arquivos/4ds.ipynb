# %%
import pandas as pd

# %%
page_html = pd.read_html("AFI's 100 Years...100 Movies - Wikipedia.html")
page_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                        Film  Release year              Director  \
#  0             Citizen Kane          1941          Orson Welles
#  1               Casablanca          1942        Michael Curtiz
#  2            The Godfather          1972  Francis Ford Coppola
#  3       Gone with the Wind          1939        Victor Fleming
#  4       Lawrence of Arabia          1962            David Lean
#  ..                     ...           ...                   ...
# ...

# %%
movies_df_1 = page_html[1]
movies_df_1
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# ...

# %%
movies_df_1.to_html('top_movies.html')

# %% [markdown]
# # XML

# %%
imdb_data = pd.read_xml('https://raw.githubusercontent.com/alura-cursos/Pandas/main/imdb_top_1000.xml')
imdb_data.sample(5)
# Out:
#      index                                        Poster_Link  \
# 64      64  https://m.media-amazon.com/images/M/MV5BNTkyOG...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
# 395    395  https://m.media-amazon.com/images/M/MV5BNWE4OT...
# 366    366  https://m.media-amazon.com/images/M/MV5BMjE0MT...
# 674    674  https://m.media-amazon.com/images/M/MV5BMDQyMD...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 64                         3 Idiots          2009          UA  170 min
# 999                    The 39 Steps          1935        None   86 min
# 395  The Nightmare Before Christmas          1993           U   76 min
# 366                        G.O.R.A.          2004        None  127 min
# 674             Dip huet seung hung          1989           R  111 min
#
#                           Genre  IMDB_Rating  \
# 64                Comedy, Drama          8.4
# 999    Crime, Mystery, Thriller          7.6
# ...
