# %%
import pandas as pd

# %%
data = pd.read_excel('POP2022_Municipios.xls', header= 1, skipfooter= 34)
data
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO POPULAÇÃO
# 0     RO       11          15  Alta Floresta D'Oeste     21558
# 1     RO       11          23              Ariquemes    100896
# 2     RO       11          31                 Cabixi      5107
# 3     RO       11          49                 Cacoal     92202
# 4     RO       11          56             Cerejeiras     15237
# ...   ..      ...         ...                    ...       ...
# 5565  GO       52       22005             Vianópolis     14046
# 5566  GO       52       22054         Vicentinópolis      8776
# 5567  GO       52       22203               Vila Boa      3686
# 5568  GO       52       22302          Vila Propício      5646
# 5569  DF       53         108               Brasília   2923369
#
# [5570 rows x 5 columns]

# %%
df_1 = data.assign(population_parenthesis = data['POPULAÇÃO'].replace(to_replace= "\(\d{1,2}\)", value= '', regex= True),
                   population = lambda x: x.loc[:, 'population_parenthesis'].replace('\.', '', regex= True))
df_1[df_1['POPULAÇÃO'].str.contains('\(', na= False)]
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:2: SyntaxWarning: invalid escape sequence '\.'
# <>:3: SyntaxWarning: invalid escape sequence '\('
# C:\Users\mhenr\AppData\Local\Temp\ipykernel_4344\3644813547.py:1: SyntaxWarning: invalid escape sequence '\('
#   df_1 = data.assign(population_parenthesis = data['POPULAÇÃO'].replace(to_replace= "\(\d{1,2}\)", value= '', regex= True),
# C:\Users\mhenr\AppData\Local\Temp\ipykernel_4344\3644813547.py:2: SyntaxWarning: invalid escape sequence '\.'
#   population = lambda x: x.loc[:, 'population_parenthesis'].replace('\.', '', regex= True))
# C:\Users\mhenr\AppData\Local\Temp\ipykernel_4344\3644813547.py:3: SyntaxWarning: invalid escape sequence '\('
#   df_1[df_1['POPULAÇÃO'].str.contains('\(', na= False)]
# ...

# %%
df_1 = data.assign(population_parenthesis = data['POPULAÇÃO'].replace(to_replace= "\(\d{1,2}\)", value= '', regex= True),
                population = lambda x: x.loc[:, 'population_parenthesis'].replace('\.', '', regex= True))
df_1[df_1['POPULAÇÃO'].str.contains('\(', na= False)]

# %%
df_1.columns
# Out:
# Index(['UF', 'COD. UF', 'COD. MUNIC', 'NOME DO MUNICÍPIO', 'POPULAÇÃO',
#        'population_parenthesis', 'population'],
#       dtype='object')

# %%
df_1 = df_1.drop(columns= ['POPULAÇÃO', 'population_parenthesis'])
df_1
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO population
# 0     RO       11          15  Alta Floresta D'Oeste      21558
# 1     RO       11          23              Ariquemes     100896
# 2     RO       11          31                 Cabixi       5107
# 3     RO       11          49                 Cacoal      92202
# 4     RO       11          56             Cerejeiras      15237
# ...   ..      ...         ...                    ...        ...
# 5565  GO       52       22005             Vianópolis      14046
# 5566  GO       52       22054         Vicentinópolis       8776
# 5567  GO       52       22203               Vila Boa       3686
# 5568  GO       52       22302          Vila Propício       5646
# 5569  DF       53         108               Brasília    2923369
#
# [5570 rows x 5 columns]

# %%
df_1 = df_1.astype({'population': 'int64'})
df_1
# Out:
#       UF  COD. UF  COD. MUNIC      NOME DO MUNICÍPIO  population
# 0     RO       11          15  Alta Floresta D'Oeste       21558
# 1     RO       11          23              Ariquemes      100896
# 2     RO       11          31                 Cabixi        5107
# 3     RO       11          49                 Cacoal       92202
# 4     RO       11          56             Cerejeiras       15237
# ...   ..      ...         ...                    ...         ...
# 5565  GO       52       22005             Vianópolis       14046
# 5566  GO       52       22054         Vicentinópolis        8776
# 5567  GO       52       22203               Vila Boa        3686
# 5568  GO       52       22302          Vila Propício        5646
# 5569  DF       53         108               Brasília     2923369
#
# [5570 rows x 5 columns]

# %%
groupby_estados = df_1.groupby('UF')[['population']].sum().reset_index()
groupby_estados
# Out:
#     UF  population
# 0   AC      829780
# 1   AL     3125254
# 2   AM     3952262
# 3   AP      774268
# 4   BA    14659023
# 5   CE     8936431
# 6   DF     2923369
# 7   ES     3975100
# 8   GO     6950976
# 9   MA     6800605
# 10  MG    20732660
# 11  MS     2833742
# 12  MT     3784239
# 13  PA     8442962
# 14  PB     4030961
# 15  PE     9051113
# 16  PI     3270174
# 17  PR    11835379
# 18  RJ    16615526
# 19  RN     3303953
# 20  RO     1616379
# 21  RR      634805
# 22  RS    11088065
# 23  SC     7762154
# 24  SE     2211868
# 25  SP    46024937
# 26  TO     1584306

# %%
groupby_estados['population'].sum()
# Out:
# 207750291

# %%
dataframe1.merge(dataframe2, on=None, how='inner', left_on='nome_coluna_dataframe1', right_on='nome_coluna_dataframe2')

# %%
df_per_capita = df_1.assign(emission_per_capita = df_1['Emission'] / df_1['population'])
df_per_capita

# %%
import plotly.express as px
